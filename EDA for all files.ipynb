# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Pt1_S1 = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt1_S1.csv')
Pt2_S1 = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt2_S1.csv')
Pt3_S1 = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt3_S1.csv')
Pt4_S1 = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt4_S1.csv')
Pt1_S2_end = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt1_S2_end.csv')
Pt2_S2_end = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt2_S2_end.csv')
Pt3_S2_end = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt3_S2_end.csv')
Pt4_S2_end = pd.read_csv('/Users/payalparida/Desktop/EEG /EEG CSV Files/Pt4_S2_end.csv')

# %%
print(Pt1_S1.columns)
print(Pt2_S1.columns)
print(Pt3_S1.columns)
print(Pt4_S1.columns)
print(Pt1_S2_end.columns)
print(Pt2_S2_end.columns)
print(Pt3_S2_end.columns)
print(Pt4_S2_end.columns)
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')
# Index(['F7', 'T3', 'T5', 'Fp1', 'F3', 'C3', 'P3', 'O1', 'Fz', 'Cz', 'Pz',
#        'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'EKG1'],
#       dtype='object')
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
# ...

# %% [markdown]
# ## Coorelation Check

# %%
Pt1_S1_cor = Pt1_S1.corr()
Pt2_S1_cor = Pt2_S1.corr()
Pt3_S1_cor = Pt3_S1.corr()
Pt4_S1_cor = Pt4_S1.corr()
Pt1_S2_end_cor = Pt1_S2_end.corr()
Pt2_S2_end_cor = Pt2_S2_end.corr()
Pt3_S2_end_cor = Pt3_S2_end.corr()
Pt4_S2_end_cor = Pt4_S2_end.corr()

# %% [markdown]
# ### Heatmap for Correlation

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(Pt1_S1_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt1_S1')
plt.show()

plt.figure(figsize=(12, 10))
sns.heatmap(Pt2_S1_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt2_S1')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(Pt3_S1_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt3_S1')
plt.show()

plt.figure(figsize=(12, 10))
sns.heatmap(Pt4_S1_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt4_S1')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(Pt1_S2_end_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt1_S2_end')
plt.show()

plt.figure(figsize=(12, 10))
sns.heatmap(Pt2_S2_end_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt2_S2_end')
plt.show()

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(Pt3_S2_end_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt3_S2_end')
plt.show()

plt.figure(figsize=(12, 10))
sns.heatmap(Pt4_S2_end_cor, annot=True, cmap='YlGnBu')
plt.title('Correlation Heatmap for Pt4_S2_end')
plt.show()

# %% [markdown]
# ### Show the variables which are having Correlation coefficient more than 0.9

# %%
for column1 in Pt1_S1_cor.columns:
    for column2 in Pt1_S1_cor.columns:
        if column1 != column2 and Pt1_S1_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# Fp1 and Fp2 are correlated above 0.9
# T5 and O1 are correlated above 0.9
# T5 and P3 are correlated above 0.9
# O1 and T5 are correlated above 0.9
# O1 and P3 are correlated above 0.9
# P3 and T5 are correlated above 0.9
# P3 and O1 are correlated above 0.9
# Fp2 and Fp1 are correlated above 0.9
# T6 and O2 are correlated above 0.9
# O2 and T6 are correlated above 0.9

# %%
for column1 in Pt2_S1_cor.columns:
    for column2 in Pt2_S1_cor.columns:
        if column1 != column2 and Pt2_S1_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# Fp2 and F4 are correlated above 0.9
# F8 and T4 are correlated above 0.9
# T4 and F8 are correlated above 0.9
# F4 and Fp2 are correlated above 0.9

# %%
for column1 in Pt3_S1_cor.columns:
    for column2 in Pt3_S1_cor.columns:
        if column1 != column2 and Pt3_S1_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# Fp1 and Fz are correlated above 0.9
# T5 and O1 are correlated above 0.9
# O1 and T5 are correlated above 0.9
# O1 and P3 are correlated above 0.9
# P3 and O1 are correlated above 0.9
# Fz and Fp1 are correlated above 0.9
# Fz and Fp2 are correlated above 0.9
# Fp2 and Fz are correlated above 0.9
# F8 and T4 are correlated above 0.9
# T4 and F8 are correlated above 0.9
# T4 and T6 are correlated above 0.9
# T6 and T4 are correlated above 0.9

# %%
for column1 in Pt4_S1_cor.columns:
    for column2 in Pt4_S1_cor.columns:
        if column1 != column2 and Pt4_S1_cor.loc[column1, column2] > 0.95:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# F7 and T3 are correlated above 0.9
# F7 and C3 are correlated above 0.9
# F7 and F8 are correlated above 0.9
# F7 and T4 are correlated above 0.9
# T3 and F7 are correlated above 0.9
# T3 and T5 are correlated above 0.9
# T3 and P3 are correlated above 0.9
# T3 and O1 are correlated above 0.9
# T3 and P4 are correlated above 0.9
# T3 and O2 are correlated above 0.9
# T3 and F8 are correlated above 0.9
# T3 and T4 are correlated above 0.9
# T3 and T6 are correlated above 0.9
# T5 and T3 are correlated above 0.9
# T5 and P3 are correlated above 0.9
# T5 and O1 are correlated above 0.9
# T5 and P4 are correlated above 0.9
# T5 and O2 are correlated above 0.9
# T5 and T4 are correlated above 0.9
# T5 and T6 are correlated above 0.9
# Fp1 and F3 are correlated above 0.9
# Fp1 and Fp2 are correlated above 0.9
# F3 and Fp1 are correlated above 0.9
# C3 and F7 are correlated above 0.9
# P3 and T3 are correlated above 0.9
# P3 and T5 are correlated above 0.9
# ...

# %%
for column1 in Pt1_S2_end_cor.columns:
    for column2 in Pt1_S2_end_cor.columns:
        if column1 != column2 and Pt1_S2_end_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")

# %%
for column1 in Pt2_S2_end_cor.columns:
    for column2 in Pt2_S2_end_cor.columns:
        if column1 != column2 and Pt2_S2_end_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")

# %%
for column1 in Pt3_S2_end_cor.columns:
    for column2 in Pt3_S2_end_cor.columns:
        if column1 != column2 and Pt3_S2_end_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# Fp1 and Fz are correlated above 0.9
# T5 and O1 are correlated above 0.9
# O1 and T5 are correlated above 0.9
# Fz and Fp1 are correlated above 0.9
# Fz and Fp2 are correlated above 0.9
# Fp2 and Fz are correlated above 0.9

# %%
for column1 in Pt4_S2_end_cor.columns:
    for column2 in Pt4_S2_end_cor.columns:
        if column1 != column2 and Pt4_S2_end_cor.loc[column1, column2] > 0.9:
            print(f"{column1} and {column2} are correlated above 0.9")
# Out:
# F7 and T3 are correlated above 0.9
# F7 and T5 are correlated above 0.9
# F7 and C3 are correlated above 0.9
# F7 and P3 are correlated above 0.9
# F7 and C4 are correlated above 0.9
# F7 and F8 are correlated above 0.9
# F7 and T4 are correlated above 0.9
# F7 and T6 are correlated above 0.9
# T3 and F7 are correlated above 0.9
# T3 and T5 are correlated above 0.9
# T3 and P3 are correlated above 0.9
# T3 and O1 are correlated above 0.9
# T3 and C4 are correlated above 0.9
# T3 and P4 are correlated above 0.9
# T3 and O2 are correlated above 0.9
# T3 and F8 are correlated above 0.9
# T3 and T4 are correlated above 0.9
# T3 and T6 are correlated above 0.9
# T5 and F7 are correlated above 0.9
# T5 and T3 are correlated above 0.9
# T5 and P3 are correlated above 0.9
# T5 and O1 are correlated above 0.9
# T5 and P4 are correlated above 0.9
# T5 and O2 are correlated above 0.9
# T5 and F8 are correlated above 0.9
# T5 and T4 are correlated above 0.9
# T5 and T6 are correlated above 0.9
# ...

# %%
Pt1_S1_remove = set()

for column1 in Pt1_S1_cor.columns:
    for column2 in Pt1_S1_cor.columns:
        if column1 != column2 and Pt1_S1_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt1_S1_remove:
                Pt1_S1_remove.add(column2)

Pt1_S1_noncor = Pt1_S1_cor.drop(Pt1_S1_remove, axis=1)

# %%
Pt1_S1.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt1_S1_noncor.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'F3', 'C3', 'Fz', 'Cz', 'F8', 'T4', 'T6', 'F4',
#        'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt2_S1_remove = set()

for column1 in Pt2_S1_cor.columns:
    for column2 in Pt2_S1_cor.columns:
        if column1 != column2 and Pt2_S1_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt2_S1_remove:
                Pt2_S1_remove.add(column2)

Pt2_S1_noncor = Pt2_S1_cor.drop(Pt2_S1_remove, axis=1)
Pt2_S1_remove
# Out:
# {'F4', 'T4'}

# %%
Pt2_S1.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt2_S1_noncor.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T6', 'O2', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt3_S1_remove = set()

for column1 in Pt3_S1_cor.columns:
    for column2 in Pt3_S1_cor.columns:
        if column1 != column2 and Pt3_S1_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt3_S1_remove:
                Pt3_S1_remove.add(column2)

Pt3_S1_noncor = Pt3_S1_cor.drop(Pt3_S1_remove, axis=1)
Pt3_S1_remove
# Out:
# {'Fz', 'O1', 'T4'}

# %%
Pt3_S1.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt3_S1_noncor.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'F3', 'C3', 'P3', 'Cz', 'Fp2', 'F8', 'T6',
#        'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt4_S1_remove = set()

for column1 in Pt4_S1_cor.columns:
    for column2 in Pt4_S1_cor.columns:
        if column1 != column2 and Pt4_S1_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt4_S1_remove:
                Pt4_S1_remove.add(column2)

Pt4_S1_noncor = Pt4_S1_cor.drop(Pt4_S1_remove, axis=1)
Pt4_S1_remove
# Out:
# {'C3',
#  'C4',
#  'F4',
#  'F8',
#  'Fp1',
#  'Fp2',
#  'Fz',
#  'O1',
#  'O2',
#  'P3',
#  'P4',
#  'T3',
#  'T4',
#  'T5',
#  'T6'}

# %%
Pt4_S1.columns
# Out:
# Index(['F7', 'T3', 'T5', 'Fp1', 'F3', 'C3', 'P3', 'O1', 'Fz', 'Cz', 'Pz',
#        'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'EKG1'],
#       dtype='object')

# %%
Pt4_S1_noncor.columns
# Out:
# Index(['F7', 'F3', 'Cz', 'Pz', 'EKG1'], dtype='object')

# %%
Pt3_S2_end_remove = set()

for column1 in Pt3_S2_end_cor.columns:
    for column2 in Pt3_S2_end_cor.columns:
        if column1 != column2 and Pt3_S2_end_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt3_S2_end_remove:
                Pt3_S2_end_remove.add(column2)

Pt3_S2_end_noncor = Pt3_S2_end_cor.drop(Pt3_S2_end_remove, axis=1)
Pt3_S2_end_remove
# Out:
# {'Fz', 'O1'}

# %%
Pt3_S2_end.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'O1', 'F3', 'C3', 'P3', 'Fz', 'Cz', 'Fp2',
#        'F8', 'T4', 'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt3_S2_end_noncor.columns
# Out:
# Index(['Fp1', 'F7', 'T3', 'T5', 'F3', 'C3', 'P3', 'Cz', 'Fp2', 'F8', 'T4',
#        'T6', 'O2', 'F4', 'C4', 'P4', 'Pz', 'EKG1'],
#       dtype='object')

# %%
Pt4_S2_end_remove = set()

for column1 in Pt4_S2_end_cor.columns:
    for column2 in Pt4_S2_end_cor.columns:
        if column1 != column2 and Pt4_S2_end_cor.loc[column1, column2] > 0.9:
            if column1 not in Pt4_S2_end_remove:
                Pt4_S2_end_remove.add(column2)

Pt4_S2_end_noncor = Pt4_S2_end_cor.drop(Pt4_S2_end_remove, axis=1)
Pt4_S2_end_remove
# Out:
# {'C3', 'C4', 'F8', 'Fp2', 'O2', 'P3', 'P4', 'T3', 'T4', 'T5', 'T6'}

# %%
Pt4_S2_end.columns
# Out:
# Index(['F7', 'T3', 'T5', 'Fp1', 'F3', 'C3', 'P3', 'O1', 'Fz', 'Cz', 'Pz',
#        'Fp2', 'F4', 'C4', 'P4', 'O2', 'F8', 'T4', 'T6', 'EKG1'],
#       dtype='object')

# %%
Pt4_S2_end_noncor.columns
# Out:
# Index(['F7', 'Fp1', 'F3', 'O1', 'Fz', 'Cz', 'Pz', 'F4', 'EKG1'], dtype='object')

# %% [markdown]
# ## Normalize or scale the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
Pt1_S1_scaled = MinMaxScaler().fit_transform(Pt2_S1_noncor)
Pt2_S1_scaled = MinMaxScaler().fit_transform(Pt2_S1_noncor)
Pt3_S1_scaled = MinMaxScaler().fit_transform(Pt3_S1_noncor)
Pt4_S1_scaled = MinMaxScaler().fit_transform(Pt4_S1_noncor)
Pt1_S2_end_scaled = MinMaxScaler().fit_transform(Pt1_S2_end_noncor)
Pt2_S2_end_scaled = MinMaxScaler().fit_transform(Pt2_S2_end_noncor)
Pt3_S2_end_scaled = MinMaxScaler().fit_transform(Pt3_S2_end_noncor)
Pt4_S2_end_scaled = MinMaxScaler().fit_transform(Pt4_S2_end_noncor)
